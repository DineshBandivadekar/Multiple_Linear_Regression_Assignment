# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# %%
toyota = pd.read_csv(r"D:\dinesh document\EXCELR\Data Science\Assingment\Multiple_Linear_Regression\ToyotaCorolla.csv",encoding= 'unicode_escape')

# %%
toyota.head(2)
# Out:
#    Id                                          Model  Price  Age_08_04  \
# 0   1  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2  TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 0                1               1      0          0            0
# 1                0               1      0          0            0
#
#    Backseat_Divider  Metallic_Rim  Radio_cassette  Tow_Bar
# 0                 1             0               0        0
# 1                 1             0               0        0
#
# [2 rows x 38 columns]

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Tow_Bar'],
#       dtype='object')

# %%
toyota['Model']
# Out:
# 0           TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# 1           TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# 2           TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# 3           TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# 4             TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors
#                               ...
# 1431           TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors
# 1432    TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...
# 1433    TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...
# 1434    TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...
# 1435          TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors
# Name: Model, Length: 1436, dtype: object

# %%
toyota1=toyota[['Price', 'Age_08_04','KM','HP','cc', 'Doors','Gears','Quarterly_Tax', 'Weight']]
toyota1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
pd.plotting.scatter_matrix(toyota1,figsize=(30,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Correletion 
toyota1.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
# Model 
m_Price=ols('Price~Age_08_04+KM+HP+cc+Gears+Gears+Quarterly_Tax+Weight',data=toyota1).fit()
vif=1/(1-m_Price.rsquared)
vif
# Out:
# 7.340127819664041

# %% [markdown]
# ### VIF is equal to 7.3401.

# %%
# Summary
m_Price.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1293.
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        15:06:56   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1428   BIC:                         2.481e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### R-squared of model is 0.864. 86% of the variance in the dependent variable explained by dependent variable. Adj.R-squared of model is 0.863..

# %%
import seaborn as sns

# %%
## Distplot of Price

# %%
sns.distplot(toyota1['Price'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ### Model Deletion

# %%
# QQ plot
import statsmodels.api as sm
qqplot=sm.qqplot(m_Price.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf

# %%
model_influence = m_Price.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(toyota1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 88.25985710286554)

# %%
k = toyota1.shape[1]
n = toyota1.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020891364902506964

# %%
influence_plot(m_Price,aplha=0.5)

y=[i for i in range(-2,8)]
x=[leverage_cutoff for i in range(10)]
plt.plot(x,y,'r+')

plt.show()

# %%
df=toyota1.drop(toyota1.index[[80]],axis=0)

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
m_df=ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=df).fit()
vif=1/(1-m_df.rsquared)
vif
# Out:
# 7.655739690418648

# %%
m_df.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     1186.
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        15:07:12   Log-Likelihood:                -12335.
# No. Observations:                1435   AIC:                         2.469e+04
# Df Residuals:                    1426   BIC:                         2.473e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# QQ plot
qqplot=sm.qqplot(m_df.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model_influence = m_df.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
# Out:
# Text(0, 0.5, 'Cooks Distance')

# %%
(np.argmax(c),np.max(c))
# Out:
# (220, 2.224461171301086)

# %%
k = df.shape[1]
n = df.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
influence_plot(m_df,aplha=0.5)

y=[i for i in range(-2,8)]
x=[leverage_cutoff for i in range(10)]
plt.plot(x,y,'r+')

plt.show()

# %%
df1=df.drop(df.index[[220]],axis=0)

# %%
m_df1=ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=df1).fit()
vif=1/(1-m_df1.rsquared)
vif
# Out:
# 8.186293038361148

# %%
m_df1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     1280.
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        15:07:17   Log-Likelihood:                -12278.
# No. Observations:                1434   AIC:                         2.457e+04
# Df Residuals:                    1425   BIC:                         2.462e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
df1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# ## Prediction of price

# %%
predict_price=m_df1.predict(df1[['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']])

# %%
predict_price
# Out:
# 0       16464.269143
# 1       16015.934400
# 2       16438.822844
# 3       16097.016263
# 4       15920.074311
#             ...
# 1431     9015.088083
# 1432     8441.533328
# 1433     8592.387585
# 1434     8710.693475
# 1435    10235.621866
# Length: 1434, dtype: float64

# %% [markdown]
# ## Graph of actual and predicted price

# %%
plt.scatter(df1['Price'],predict_price)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=df1[['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
y=df1.loc[:,'Price']

# %%
x
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0            23  46986   90  2000      3      5            210    1165
# 1            23  72937   90  2000      3      5            210    1165
# 2            24  41711   90  2000      3      5            210    1165
# 3            26  48000   90  2000      3      5            210    1165
# 4            30  38500   90  2000      3      5            210    1170
# ...         ...    ...  ...   ...    ...    ...            ...     ...
# 1431         69  20544   86  1300      3      5             69    1025
# 1432         72  19000   86  1300      3      5             69    1015
# 1433         71  17016   86  1300      3      5             69    1015
# 1434         70  16916   86  1300      3      5             69    1015
# 1435         76      1  110  1600      5      5             19    1114
#
# [1434 rows x 8 columns]

# %%
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1434, dtype: int64

# %%
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#       Age_08_04        KM        HP        cc     Doors     Gears  \
# 0     -1.774309 -0.575432 -0.766888  2.313661 -1.083747 -0.140525
# 1     -1.774309  0.116644 -0.766888  2.313661 -1.083747 -0.140525
# 2     -1.720505 -0.716108 -0.766888  2.313661 -1.083747 -0.140525
# 3     -1.612896 -0.548390 -0.766888  2.313661 -1.083747 -0.140525
# 4     -1.397678 -0.801741 -0.766888  2.313661 -1.083747 -0.140525
# ...         ...       ...       ...       ...       ...       ...
# 1429   0.700696 -1.280602 -1.033859 -1.424784 -1.083747 -0.140525
# 1430   0.862110 -1.321778 -1.033859 -1.424784 -1.083747 -0.140525
# 1431   0.808305 -1.374689 -1.033859 -1.424784 -1.083747 -0.140525
# 1432   0.754501 -1.377355 -1.033859 -1.424784 -1.083747 -0.140525
# 1433   1.077328 -1.828454  0.567964  0.177407  1.016379 -0.140525
#
#       Quarterly_Tax    Weight
# 0          2.991758  1.838135
# 1          2.991758  1.838135
# 2          2.991758  1.838135
# 3          2.991758  1.838135
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
mse=mean_squared_error(y,predict_price)
mae=mean_absolute_error(y,predict_price)
rmse=np.sqrt(mse)
print('mae',mae)
print('RMSE',rmse)
print('The mean squared value is:',mse)
print('The R2 score is:',r2_score(y,predict_price))
# Out:
# mae 936.9231342856143
# RMSE 1265.720000354872
# The mean squared value is: 1602047.119298337
# The R2 score is: 0.8778445878599779

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %% [markdown]
# ## Lasso Regression

# %%
lasso=Lasso()
lasso.fit(x,y)
lassoy=lasso.predict(x)
print(lasso.score(x,y))
# Out:
# 0.8778433458771199

# %% [markdown]
# ## Ridge Regression

# %%
ridge=Ridge()
ridge.fit(x,y)
yridge=ridge.predict(x)
print(ridge.score(x,y))
# Out:
# 0.877844242452044
